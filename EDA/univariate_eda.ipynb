# %%
import pandas as pd
import seaborn as sns
from matplotlib.pyplot import figure
# %matplotlib inline

# %%
df = pd.read_csv('features_3_sec.csv')

# %%
df.head()
# Out:
#             filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0  blues.00000.0.wav   66149          0.335406         0.091048  0.130405
# 1  blues.00000.1.wav   66149          0.343065         0.086147  0.112699
# 2  blues.00000.2.wav   66149          0.346815         0.092243  0.132003
# 3  blues.00000.3.wav   66149          0.363639         0.086856  0.132565
# 4  blues.00000.4.wav   66149          0.335579         0.088129  0.143289
#
#     rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0  0.003521             1773.065032          167541.630869
# 1  0.001450             1816.693777           90525.690866
# 2  0.004620             1788.539719          111407.437613
# 3  0.002448             1655.289045          111952.284517
# 4  0.001701             1630.656199           79667.267654
#
#    spectral_bandwidth_mean  spectral_bandwidth_var  ...  mfcc16_var  \
# 0              1972.744388           117335.771563  ...   39.687145
# ...

# %% [markdown]
# # overall univariate plots is the task

# %%
df.columns
# Out:
# Index(['filename', 'length', 'chroma_stft_mean', 'chroma_stft_var', 'rms_mean',
#        'rms_var', 'spectral_centroid_mean', 'spectral_centroid_var',
#        'spectral_bandwidth_mean', 'spectral_bandwidth_var', 'rolloff_mean',
#        'rolloff_var', 'zero_crossing_rate_mean', 'zero_crossing_rate_var',
#        'harmony_mean', 'harmony_var', 'perceptr_mean', 'perceptr_var', 'tempo',
#        'mfcc1_mean', 'mfcc1_var', 'mfcc2_mean', 'mfcc2_var', 'mfcc3_mean',
#        'mfcc3_var', 'mfcc4_mean', 'mfcc4_var', 'mfcc5_mean', 'mfcc5_var',
#        'mfcc6_mean', 'mfcc6_var', 'mfcc7_mean', 'mfcc7_var', 'mfcc8_mean',
#        'mfcc8_var', 'mfcc9_mean', 'mfcc9_var', 'mfcc10_mean', 'mfcc10_var',
#        'mfcc11_mean', 'mfcc11_var', 'mfcc12_mean', 'mfcc12_var', 'mfcc13_mean',
#        'mfcc13_var', 'mfcc14_mean', 'mfcc14_var', 'mfcc15_mean', 'mfcc15_var',
#        'mfcc16_mean', 'mfcc16_var', 'mfcc17_mean', 'mfcc17_var', 'mfcc18_mean',
# ...

# %%
df.describe()
# Out:
#         length  chroma_stft_mean  chroma_stft_var     rms_mean       rms_var  \
# count   9990.0       9990.000000      9990.000000  9990.000000  9.990000e+03
# mean   66149.0          0.379534         0.084876     0.130859  2.676388e-03
# std        0.0          0.090466         0.009637     0.068545  3.585628e-03
# min    66149.0          0.107108         0.015345     0.000953  4.379535e-08
# 25%    66149.0          0.315698         0.079833     0.083782  6.145900e-04
# 50%    66149.0          0.384741         0.085108     0.121253  1.491318e-03
# 75%    66149.0          0.442443         0.091092     0.176328  3.130862e-03
# max    66149.0          0.749481         0.120964     0.442567  3.261522e-02
#
#        spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# count             9990.000000           9.990000e+03              9990.000000
# mean              2199.219431           4.166727e+05              2241.385959
# ...

# %%
figure(figsize=(8, 6), dpi=80)
sns.scatterplot(data = df, x = "label", y = "chroma_stft_mean")

# %% [markdown]
# chroma ~ pitch

# %%
figure(figsize=(10, 8), dpi=80)
sns.scatterplot(data = df, x = 'spectral_centroid_mean', y = 'chroma_stft_mean', hue = 'label')

# %% [markdown]
# quick note: definitely should have made the previous graph less sparse, but didn't quite figure out how to do that without losing data--
#
# We can see that overall, there's a loose positive correlation between spectral centroid and chroma stft. Higher centroid values denote higher frequencies being louder than lower frequencies, and chroma values denote pitch, more or less (correct me if this is wrong!). So basically, we're seeing that generally, higher pitches are played at louder frequencies than lower notes... (right??)
#
# There are also some things to be said regarding genre - the chroma & spectral centroid mean values tend to cluster together within a genre - maybe we can look into why this is more in the future (like it looks like jazz has a higher frequency of low notes, metal has louder, higher pitched notes, rock has a lot of variation, etc).

# %%
#figure(figsize=(10, 8), dpi=80)
#sns.scatterplot(data = df, x = 'rms_mean', y = 'spectral_bandwidth_mean', hue = 'label')
